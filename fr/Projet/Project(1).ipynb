# %% [markdown]
# # Projet Big Data : Partie 1
#
# ## I] Collecte de données et étiquetage et annotation :

# %%
import os
def create_folder():
    if not os.path.exists('images'):
        os.makedirs('images')
    return

create_folder()

# %%
#Get our images on wikidata by a request
import sys
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

# Get cities
query = """SELECT DISTINCT ?grandeville ?grandevilleLabel ?pays ?paysLabel ?image {
  # ?grandeville wdt:P31 wd:Q1549591;
               wdt:P17 ?pays;
               wdt:P18 ?image.
 SERVICE wikibase:label { bd:serviceParam wikibase:language "fr". }
}
LIMIT 100"""

#fonction qui va exécuter notre requête vers wikidata
def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (
        sys.version_info[0],
        sys.version_info[1],
    )
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


array = []
results = get_results(endpoint_url, query)

for result in results["results"]["bindings"]:
    array.append(
        (
            result["grandevilleLabel"]["value"],
            result["paysLabel"]["value"],
            result["image"]["value"],
        )
    )
# Out:
# C:\Users\adrie\AppData\Local\Temp\ipykernel_19380\3871241469.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Put in a dataframe the data
dataframe = pd.DataFrame(array, columns=["ville", "pays", "image"])
dataframe = dataframe.astype(
    dtype={"ville": "<U200", "pays": "<U200", "image": "<U200"}
)
dataframe
# Out:
#           ville                pays  \
# 0         Forlì              Italie
# 1         Erode                Inde
# 2      Sarajevo  Bosnie-Herzégovine
# 3       Cardiff         Royaume-Uni
# 4        Austin          États-Unis
# ..          ...                 ...
# 95  Gandhinagar                Inde
# 96    Arlington          États-Unis
# 97       Butwal               Népal
# 98   Anderlecht            Belgique
# 99       Canton               Chine
#
#                                                 image
# 0   http://commons.wikimedia.org/wiki/Special:File...
# 1   http://commons.wikimedia.org/wiki/Special:File...
# 2   http://commons.wikimedia.org/wiki/Special:File...
# 3   http://commons.wikimedia.org/wiki/Special:File...
# 4   http://commons.wikimedia.org/wiki/Special:File...
# ..                                                ...
# 95  http://commons.wikimedia.org/wiki/Special:File...
# 96  http://commons.wikimedia.org/wiki/Special:File...
# 97  http://commons.wikimedia.org/wiki/Special:File...
# 98  http://commons.wikimedia.org/wiki/Special:File...
# 99  http://commons.wikimedia.org/wiki/Special:File...
#
# [100 rows x 3 columns]

# %%
import os
import re
import requests
from PIL import Image
from io import BytesIO
from urllib.parse import urlparse, unquote


def download_image(url):
    # Check if the URL ends with '.jpg' or '.png'
    if not url.endswith(('.jpg', '.JPG')):
        print('Skipping unsupported image URL:', url)
        return
    
    # Créez un dossier nommé "images" s'il n'existe pas déjà
    if not os.path.exists("images"):
        os.makedirs("images")
    
    # Clean URL
    url = unquote(url)

    # Extract the image name from the URL
    match = re.search(r'/([^/]+)\.(jpg|JPG)$', url)
    if match:
        filename = match.group(1) + '.' + match.group(2)
    else:
        filename = 'image.jpg'

    # Create the output path by combining the output folder and the filename
    output_path = os.path.join("images", filename)
    
    if os.path.exists(output_path):
        print('Image already exists:', output_path)
        return
    
    # Once we verified everything, we can download the image
    headers = {"User-Agent": "Mozilla/5.0"}
    request = requests.get(url, allow_redirects=True, headers=headers)
    
    if request.status_code == 200:
        img = Image.open(BytesIO(request.content))
        
        # Get the EXIF data from the original image and save it to the new image
        exif_data = img.getexif()
        if exif_data is not None:
            img.save(output_path, exif=exif_data)
        else:
            img.save(output_path)
        
        return f"Image enregistrée avec succès dans le dossier 'images' : {filename}"
    else:
        return f"Échec de la requête avec le code d'état : {request.status_code}"

# %%
# We call the download fonction
dataframe.image.apply(download_image)
# Out:
# Image already exists: images\Forlì, piazza aurelio saffi, palazzo municipale 01.jpg
# Image already exists: images\Cauvery at Erode.JPG
# Image already exists: images\Sarajevo City Panorama.JPG
# Image already exists: images\Cardiffmontage3.jpg
# Image already exists: images\AustinSkylineLouNeffPoint-2010-03-29-b.JPG
# Image already exists: images\Fort Worth June 2016 68 (skyline).jpg
# Image already exists: images\Long Beach 06.jpg
# Image already exists: images\Piazza d'Italia di Sassari.JPG
# Image already exists: images\SanJose Infobox Pic Montage.jpg
# Image already exists: images\Centrum Eindhoven.jpg
# Image already exists: images\Panorama of Macau Peninsula2021.jpg
# Image already exists: images\Detroit montage 2020.jpg
# Image already exists: images\2006-03-26 Denver Skyline I-25 Speer.jpg
# Image already exists: images\Marité.jpg
# Image already exists: images\Reggio emilia piazza san prospero abside duomo.jpg
# Image already exists: images\El Paso Skyline.jpg
# Image already exists: images\Tirana from South.jpg
# Image already exists: images\Brno, Štýřice, Pražákova, výhled z AZ Toweru (2013-05-22; 28).jpg
# Image already exists: images\Mysore Palace, India (photo - Jim Ankan Deka).jpg
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/JXFL2011N.png
# Image already exists: images\L'Hospitalet de Llobregat.jpg
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Nanjing%20View.png
# Image already exists: images\Montage Columbus 1.jpg
# Image already exists: images\Waikiki view from Diamond Head.JPG
# Image already exists: images\Salem Seelanaickenpati.jpg
# Image already exists: images\Amberes; vistas MAS 2.jpg
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Daegu%20montage.png
# Image already exists: images\Brest - Le Château - PA00089847 - 011.JPG
# Image already exists: images\Los tribunales de justicia, La Catedral y la Plaza de armas.jpg
# Image already exists: images\Montaje de La Serena.jpg
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Dallas%20Collage%20Montage.png
# Image already exists: images\Nha Trang skyline.jpg
# Image already exists: images\Sabadell - Eix Macià.jpg
# Image already exists: images\Siem Reap City.jpg
# Image already exists: images\Providence RI skyline2.jpg
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Cbe%20Montage.png
# Image already exists: images\Pervouralsk citysign.jpg
# Image already exists: images\.00 2367 Darwin Australien - State Square.jpg
# Image already exists: images\00 2474 Darwin (Northern Territory, Australien).jpg
# Image already exists: images\Piazza del Duomo e Cattedrale Santo Stefano Prato.jpg
# Image already exists: images\Барысаўскі Васкрасенскі сабор 08.JPG
# Image already exists: images\OAKLAND, CA, USA - Skyline and Bridge.JPG
# Image already exists: images\Sakurajima -城山展望台より.jpg
# Image already exists: images\Вокзал в Армавире.jpg
# Image already exists: images\Vista de Alicante, España, 2014-07-04, DD 49.JPG
# Image already exists: images\16-07-06-Rathaus Graz Turmblick-RR2 0275.jpg
# Image already exists: images\Ortigia dall'alto.jpg
# Image already exists: images\Urumqi Skyline July 2019.jpg
# Image already exists: images\Phoenix, Arizona.JPG
# Image already exists: images\Sacramento Riverfront.jpg
# Image already exists: images\Nhà thờ chính Văn miếu Trấn Biên.jpg
# Image already exists: images\Messina harbour - aerial view.jpg
# Image already exists: images\Saskatoon Montage 2020.jpg
# Image already exists: images\Tychy. Kościół p.w. św. Magdaleny1.JPG
# Image already exists: images\Okn-073-1.jpg
# Image already exists: images\Houston montage.jpg
# Image already exists: images\Curico vom Cerro aus.JPG
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Iquique%20wiki.png
# Skipping unsupported image URL: http://commons.wikimedia.org/wiki/Special:FilePath/Simferopol%20Montage.png
# Image already exists: images\White Tower and Beach front.jpg
# Image already exists: images\Memphis skyline from the air.jpg
# Image already exists: images\Castellón aéreo 2 (36985918570).jpg
# Image already exists: images\Paranaque City.JPG
# Image already exists: images\Wikibelfast1.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # We call the download fonction
# ----> 2 dataframe.image.apply(download_image)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[4], line 46, in download_image(url)
#      44 exif_data = img.getexif()
#      45 if exif_data is not None:
# ---> 46     img.save(output_path, exif=exif_data)
#      47 else:
#      48     img.save(output_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\Image.py:2439, in Image.save(self, fp, format, **params)
#    2436         fp = builtins.open(filename, "w+b")
#    2438 try:
# -> 2439     save_handler(self, fp, filename)
#    2440 except Exception:
#    2441     if open_fp:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\JpegImagePlugin.py:777, in _save(im, fp, filename)
#     775 exif = info.get("exif", b"")
#     776 if isinstance(exif, Image.Exif):
# --> 777     exif = exif.tobytes()
#     778 if len(exif) > MAX_BYTES_IN_MARKER:
#     779     msg = "EXIF data is too long"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\Image.py:3798, in Exif.tobytes(self, offset)
#    3796             value[ExifTags.IFD.Interop] = self.get_ifd(ExifTags.IFD.Interop)
#    3797     ifd[tag] = value
# -> 3798 return b"Exif\x00\x00" + head + ifd.tobytes(offset)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\TiffImagePlugin.py:898, in ImageFileDirectory_v2.tobytes(self, offset)
#     896     for ifd_tag, ifd_value in values.items():
#     897         ifd[ifd_tag] = ifd_value
# --> 898     data = ifd.tobytes(offset)
#     899 else:
#     900     values = value if isinstance(value, tuple) else (value,)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\TiffImagePlugin.py:901, in ImageFileDirectory_v2.tobytes(self, offset)
#     899 else:
#     900     values = value if isinstance(value, tuple) else (value,)
# --> 901     data = self._write_dispatch[typ](self, *values)
#     903 tagname = TiffTags.lookup(tag, self.group).name
#     904 typname = "ifd" if is_ifd else TYPES.get(typ, "unknown")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\TiffImagePlugin.py:766, in ImageFileDirectory_v2.write_rational(self, *values)
#     764 @_register_writer(5)
#     765 def write_rational(self, *values):
# --> 766     return b"".join(
#     767         self._pack("2L", *_limit_rational(frac, 2**32 - 1)) for frac in values
#     768     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\TiffImagePlugin.py:767, in <genexpr>(.0)
#     764 @_register_writer(5)
#     765 def write_rational(self, *values):
#     766     return b"".join(
# --> 767         self._pack("2L", *_limit_rational(frac, 2**32 - 1)) for frac in values
#     768     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\PIL\TiffImagePlugin.py:283, in _limit_rational(val, max_val)
#     282 def _limit_rational(val, max_val):
# --> 283     inv = abs(val) > 1
#     284     n_d = IFDRational(1 / val if inv else val).limit_rational(max_val)
#     285     return n_d[::-1] if inv else n_d
#
# TypeError: bad operand type for abs(): 'str'

# %%
from PIL import Image
import os

def redimensionner_images(dossier_images, largeur, hauteur):
    """
    Redimensionne toutes les images dans un dossier donné.

    Args:
    - dossier_images (str): Chemin vers le dossier contenant les images.
    - largeur (int): Largeur cible pour le redimensionnement.
    - hauteur (int): Hauteur cible pour le redimensionnement.
    """
    # Vérifier si le dossier existe
    if not os.path.exists(dossier_images):
        print("Le dossier spécifié n'existe pas.")
        return

    # Liste des extensions d'images supportées
    extensions = ['.jpg', '.jpeg', '.png']

    # Parcourir tous les fichiers dans le dossier
    for fichier in os.listdir(dossier_images):
        # Vérifier si c'est un fichier d'image
        if any(fichier.lower().endswith(ext) for ext in extensions):
            chemin_image = os.path.join(dossier_images, fichier)
            try:
                # Ouvrir l'image
                image = Image.open(chemin_image)
                # Redimensionner l'image
                image_redimensionnee = image.resize((largeur, hauteur), Image.Resampling.LANCZOS)
                # Enregistrer l'image redimensionnée, écrasant l'originale
                image_redimensionnee.save(chemin_image)
                print(f"Image {fichier} redimensionnée avec succès.")
            except Exception as e:
                print(f"Impossible de redimensionner l'image {fichier}: {e}")

# Utilisation de la fonction
dossier_images = "images"
largeur_cible = 800
hauteur_cible = 600

redimensionner_images(dossier_images, largeur_cible, hauteur_cible)
# Out:
# Image 00 3178 Sydney, Australia.jpg redimensionnée avec succès.
# Image 15-Nouakchott-eH-R0058185.jpg redimensionnée avec succès.
# Image 20130610 - Monumento aos Heróis da Independência.jpg redimensionnée avec succès.
# Image Addis abeba meskele square.jpg redimensionnée avec succès.
# Image Alger monochrome.jpg redimensionnée avec succès.
# Image Algiers Grand Post.jpg redimensionnée avec succès.
# Image Algiers Icon.png redimensionnée avec succès.
# Image Algiers in the morning.jpg redimensionnée avec succès.
# Image Algiers Montage.png redimensionnée avec succès.
# Image Algiers's Airport.jpg redimensionnée avec succès.
# Image AMMAN 2.jpg redimensionnée avec succès.
# Image AnkonPanorama.jpg redimensionnée avec succès.
# Image Argel 3.jpg redimensionnée avec succès.
# Image Asmara2.jpg redimensionnée avec succès.
# Image Asunción Paraguay.jpg redimensionnée avec succès.
# Image At night in Algiers, Algeria.jpg redimensionnée avec succès.
# Image Ausblick Bergisch Gladbach.jpg redimensionnée avec succès.
# Image Avenida Bolivar A Chavez.jpg redimensionnée avec succès.
# Image Bangui City Centre.jpg redimensionnée avec succès.
# Image Bari - Piazza del Ferrarese.JPG redimensionnée avec succès.
# Image Beirutcity.jpg redimensionnée avec succès.
# Image Beograd collage.jpg redimensionnée avec succès.
# Image Blick vom Rathausturm über Gera.jpg redimensionnée avec succès.
# Image Bottrop - Altmarkt 02 ies.jpg redimensionnée avec succès.
# Image Bujumbura.JPG redimensionnée avec succès.
# Image Canberra from Mt Ainslie (5642431515).jpg redimensionnée avec succès.
# Image Central accra-2.jpg redimensionnée avec succès.
# Image Central Algeria at night.jpg redimensionnée avec succès.
# Image CintaCosteraPanama.jpg redimensionnée avec succès.
# Image Ciprefectyakro.JPG redimensionnée avec succès.
# Image Cityscape of San José, Costa Rica (253552473).jpg redimensionnée avec succès.
# Image Ciudad de Chillán.png redimensionnée avec succès.
# Image Cottbus 07-2017 img10 aerial.jpg redimensionnée avec succès.
# Image Damascus, Syria, Panorama at sunset.jpg redimensionnée avec succès.
# Image Djibouti City.jpg redimensionnée avec succès.
# Image Dom R1.jpg redimensionnée avec succès.
# Image Dom zu paderborn1.jpg redimensionnée avec succès.
# Image Elizabeth Quay February 2016 (cropped).jpg redimensionnée avec succès.
# Image Erlangen 08-2012.jpg redimensionnée avec succès.
# Image Freetown-aerialview.jpg redimensionnée avec succès.
# Image Fuerther Innenstadt Mrz 2020.jpg redimensionnée avec succès.
# Image Goettingen Marktplatz Oct06 Antilived.jpg redimensionnée avec succès.
# Image Hagen Rathausplatz.jpg redimensionnée avec succès.
# Image Hamm Luftbild Innenstadt 2007.jpg redimensionnée avec succès.
# Image Heidelberg corr.jpg redimensionnée avec succès.
# Image Herne, Blick auf Europaplatz mit Kreuzkirche.jpg redimensionnée avec succès.
# Image Hildesheim - Blick vom Berghözchen.jpg redimensionnée avec succès.
# Image Imagelomé20.jpg redimensionnée avec succès.
# Image Ingolstadt Altes Rathaus 2012 02.jpg redimensionnée avec succès.
# Image Kasbah des Oudaias P1060356.JPG redimensionnée avec succès.
# Image Kathmandu Avion 01.JPG redimensionnée avec succès.
# Image Koblenz - Panorama von Festung Ehrenbreitstein.jpg redimensionnée avec succès.
# Image Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg redimensionnée avec succès.
# Image Libreville1.jpg redimensionnée avec succès.
# Image Ludwigshafenmitte ausderluft.jpg redimensionnée avec succès.
# Image Malabo a 13-oct-01.jpg redimensionnée avec succès.
# Image Marcus Aurelius Arch Tripoli Libya.jpg redimensionnée avec succès.
# Image Melbourne montage 6.jpg redimensionnée avec succès.
# Image Moers schloss 211204.jpg redimensionnée avec succès.
# Image MonroviaLB14.png redimensionnée avec succès.
# Image Montaje de Antofagasta.jpg redimensionnée avec succès.
# Image Neuss, Rathaus 2008.JPG redimensionnée avec succès.
# Image Niamey night.jpg redimensionnée avec succès.
# Image Nicosia 01-2017 img23 View from Shacolas Tower.jpg redimensionnée avec succès.
# Image Offenbacher-mainbogen-flussabwärts001.jpg redimensionnée avec succès.
# Image Old city of Maskat.jpg redimensionnée avec succès.
# Image Osnabrück Schloss.JPG redimensionnée avec succès.
# Image Panorama Nagold, Stadtkirche und Enz (1).jpg redimensionnée avec succès.
# Image Panoramique du centre de Tunis (3197369985) (cropped).jpg redimensionnée avec succès.
# Image Paramaribo city collage.png redimensionnée avec succès.
# Image Perugia panoramic.jpg redimensionnée avec succès.
# Image Place de la nation2 (Tchad).jpg redimensionnée avec succès.
# Image Place Memorial auz Heros Nationaux in Burkina Faso, 2009.jpg redimensionnée avec succès.
# Image Pointe des Almadies - Senegal.jpg redimensionnée avec succès.
# Image Praia Harbor.jpg redimensionnée avec succès.
# Image Quartier OCH.jpg redimensionnée avec succès.
# Image Recklinghausen, Rathaus -- 2015 -- 7398.jpg redimensionnée avec succès.
# Image Regensburg 08 2006 2.jpg redimensionnée avec succès.
# Image Remscheid rathaus.jpg redimensionnée avec succès.
# Image Residenzschloss Darmstadt 539-Gdh.JPG redimensionnée avec succès.
# Image Reutlingen Tübinger Tor 2012-04.jpg redimensionnée avec succès.
# Image Salzgitter Stahlwerk.jpg redimensionnée avec succès.
# Image San Salvador Montage.jpg redimensionnée avec succès.
# Image Santiago en invierno.jpg redimensionnée avec succès.
# Image Schloss Broich 0504.jpg redimensionnée avec succès.
# Image Schloss Wolfsburg Sued-West.JPG redimensionnée avec succès.
# Image Schlosswache mit Lambertikirche.jpg redimensionnée avec succès.
# Image Siegen - panoramio (9).jpg redimensionnée avec succès.
# Image Solingen Innenstadt 002.JPG redimensionnée avec succès.
# Image Sucre capital de Bolivia.jpg redimensionnée avec succès.
# Image Tambov TransgfigurationCathedral 101 0477.jpg redimensionnée avec succès.
# Image Tegucigalpa desde el picacho en septiembre.jpg redimensionnée avec succès.
# Image The National Assembly Globe.jpg redimensionnée avec succès.
# Image Trier 126x.jpg redimensionnée avec succès.
# Image Ulm Donauschwabenufer1.jpg redimensionnée avec succès.
# Image Witten 20090218.jpg redimensionnée avec succès.
# Image Zentrum Jenas 2008-05-24.JPG redimensionnée avec succès.
# Image Белгород с аэростата 5 августа 2014 10.jpg redimensionnée avec succès.
# Image Главное здание управления ЮВЖД.jpg redimensionnée avec succès.
# Image Краснодар.png redimensionnée avec succès.

# %%
import os
from PIL import Image, ExifTags
import json
import numpy as np
from sklearn.cluster import KMeans
from skimage import io, color

def extract_image_metadata(image_path):
    image_metadata = {}
    try:
        with Image.open(image_path) as img:
            print(image_path)
            image_metadata['filename'] = img.filename
            image_metadata['size'] = img.size
            image_metadata['format'] = img.format
            image_metadata['mode'] = img.mode
            if 'exif' in img.info:
                exif_data = {ExifTags.TAGS[k]: v for k, v in img._getexif().items() if k in ExifTags.TAGS and type(v) != bytes}
                image_metadata['exif'] = exif_data


            # Extraire les couleurs prédominantes
            img = color.rgb2lab(io.imread(image_path))
            reshaped = img.reshape(-1, 3)
            kmeans = KMeans(n_clusters=3)
            kmeans.fit(reshaped)
            lab_values = kmeans.cluster_centers_.tolist()

            # Convertir les valeurs LAB en RGB
            rgb_values = color.lab2rgb(lab_values)

            # Mettre à l'échelle les valeurs RGB entre 0 et 255
            rgb_values *= 255
            rgb_values = np.round(rgb_values).astype(np.uint8).tolist()

            image_metadata['dominant_colors'] = rgb_values
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")
    return image_metadata

def save_metadata_to_json(metadata, output_file):
    with open(output_file, 'w') as json_file:
        json.dump(metadata, json_file, indent=4)

# Chemin vers le dossier contenant les images
images_folder = "images"

# Liste pour stocker les métadonnées de chaque image
images_metadata = []

# Parcourir toutes les images dans le dossier
for filename in os.listdir(images_folder):
    if filename.endswith(('.jpg', '.jpeg', '.png')):  # Filtrer les types de fichiers d'image pris en charge
        image_path = os.path.join(images_folder, filename)
        metadata = extract_image_metadata(image_path)
        if metadata:
            # Ajouter les métadonnées extraites à la liste
            print(metadata)
            images_metadata.append(metadata)
            # Enregistrer les métadonnées dans un fichier JSON avec le même nom que l'image
            output_file = os.path.splitext(image_path)[0] + '.json'
            save_metadata_to_json(metadata, output_file)

# Enregistrer toutes les métadonnées dans un seul fichier JSON
all_metadata_file = "all_images_metadata.json"
save_metadata_to_json(images_metadata, all_metadata_file)
# Out:
# images\00 3178 Sydney, Australia.jpg
# {'filename': 'images\\00 3178 Sydney, Australia.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[102, 120, 161], [149, 137, 138], [56, 56, 57]]}
# images\15-Nouakchott-eH-R0058185.jpg
# {'filename': 'images\\15-Nouakchott-eH-R0058185.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[46, 31, 34], [175, 151, 154], [112, 89, 96]]}
# images\20130610 - Monumento aos Heróis da Independência.jpg
# {'filename': 'images\\20130610 - Monumento aos Heróis da Independência.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[203, 213, 221], [178, 144, 114], [65, 63, 25]]}
# images\Addis abeba meskele square.jpg
# {'filename': 'images\\Addis abeba meskele square.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[69, 67, 56], [115, 167, 205], [180, 156, 115]]}
# images\Alger monochrome.jpg
# {'filename': 'images\\Alger monochrome.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[187, 187, 187], [22, 22, 22], [88, 88, 88]]}
# images\Algiers Grand Post.jpg
# {'filename': 'images\\Algiers Grand Post.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[11, 9, 12], [173, 174, 181], [103, 93, 91]]}
# images\Algiers Icon.png
# Error processing image images\Algiers Icon.png: the input array must have size 3 along `channel_axis`, got (600, 800, 4)
# {'filename': 'images\\Algiers Icon.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGBA'}
# images\Algiers in the morning.jpg
# {'filename': 'images\\Algiers in the morning.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[106, 95, 74], [187, 178, 163], [37, 32, 26]]}
# images\Algiers Montage.png
# Error processing image images\Algiers Montage.png: the input array must have size 3 along `channel_axis`, got (600, 800, 4)
# {'filename': 'images\\Algiers Montage.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGBA'}
# images\Algiers's Airport.jpg
# {'filename': "images\\Algiers's Airport.jpg", 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[91, 109, 71], [164, 188, 156], [45, 51, 31]]}
# images\AMMAN 2.jpg
# {'filename': 'images\\AMMAN 2.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[215, 204, 196], [46, 34, 30], [135, 104, 78]]}
# images\AnkonPanorama.jpg
# {'filename': 'images\\AnkonPanorama.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[150, 124, 113], [133, 149, 177], [71, 73, 76]]}
# images\Argel 3.jpg
# {'filename': 'images\\Argel 3.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[118, 112, 103], [51, 56, 61], [151, 163, 183]]}
# images\Asmara2.jpg
# {'filename': 'images\\Asmara2.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[164, 141, 112], [69, 57, 43], [85, 101, 126]]}
# images\Asunción Paraguay.jpg
# {'filename': 'images\\Asunción Paraguay.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[65, 64, 57], [149, 170, 194], [179, 172, 157]]}
# images\At night in Algiers, Algeria.jpg
# {'filename': 'images\\At night in Algiers, Algeria.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[124, 119, 109], [33, 32, 30], [10, 65, 138]]}
# images\Ausblick Bergisch Gladbach.jpg
# {'filename': 'images\\Ausblick Bergisch Gladbach.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[222, 239, 244], [38, 45, 37], [94, 104, 92]]}
# images\Avenida Bolivar A Chavez.jpg
# {'filename': 'images\\Avenida Bolivar A Chavez.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[36, 51, 42], [157, 95, 66], [132, 140, 95]]}
# images\Bangui City Centre.jpg
# {'filename': 'images\\Bangui City Centre.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[125, 102, 72], [178, 187, 193], [224, 143, 93]]}
# images\Beirutcity.jpg
# {'filename': 'images\\Beirutcity.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[32, 66, 132], [25, 31, 48], [105, 136, 172]]}
# images\Beograd collage.jpg
# {'filename': 'images\\Beograd collage.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[78, 75, 63], [205, 213, 214], [72, 123, 183]]}
# images\Blick vom Rathausturm über Gera.jpg
# {'filename': 'images\\Blick vom Rathausturm über Gera.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[190, 198, 213], [74, 67, 62], [141, 125, 112]]}
# images\Bottrop - Altmarkt 02 ies.jpg
# {'filename': 'images\\Bottrop - Altmarkt 02 ies.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[55, 55, 63], [142, 139, 144], [169, 210, 251]]}
# images\Canberra from Mt Ainslie (5642431515).jpg
# {'filename': 'images\\Canberra from Mt Ainslie (5642431515).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[55, 51, 37], [162, 169, 190], [106, 103, 104]]}
# images\Central accra-2.jpg
# {'filename': 'images\\Central accra-2.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[105, 104, 98], [220, 220, 219], [160, 156, 154]]}
# images\Central Algeria at night.jpg
# {'filename': 'images\\Central Algeria at night.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[89, 35, 11], [22, 9, 4], [196, 125, 55]]}
# images\CintaCosteraPanama.jpg
# {'filename': 'images\\CintaCosteraPanama.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[161, 187, 225], [57, 53, 43], [194, 168, 125]]}
# images\Cityscape of San José, Costa Rica (253552473).jpg
# {'filename': 'images\\Cityscape of San José, Costa Rica (253552473).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[37, 32, 32], [90, 83, 82], [198, 172, 164]]}
# images\Ciudad de Chillán.png
# {'filename': 'images\\Ciudad de Chillán.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGB', 'dominant_colors': [[39, 34, 34], [180, 198, 207], [165, 130, 87]]}
# images\Cottbus 07-2017 img10 aerial.jpg
# {'filename': 'images\\Cottbus 07-2017 img10 aerial.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[160, 175, 199], [102, 102, 109], [54, 64, 48]]}
# images\Damascus, Syria, Panorama at sunset.jpg
# {'filename': 'images\\Damascus, Syria, Panorama at sunset.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[185, 179, 171], [58, 60, 58], [120, 116, 109]]}
# images\Djibouti City.jpg
# {'filename': 'images\\Djibouti City.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[214, 219, 233], [49, 49, 44], [123, 115, 114]]}
# images\Dom R1.jpg
# {'filename': 'images\\Dom R1.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[127, 107, 101], [176, 185, 197], [50, 45, 44]]}
# images\Dom zu paderborn1.jpg
# {'filename': 'images\\Dom zu paderborn1.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[89, 86, 84], [103, 122, 186], [181, 181, 173]]}
# images\Elizabeth Quay February 2016 (cropped).jpg
# {'filename': 'images\\Elizabeth Quay February 2016 (cropped).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[58, 64, 78], [128, 156, 204], [153, 147, 139]]}
# images\Erlangen 08-2012.jpg
# {'filename': 'images\\Erlangen 08-2012.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[156, 119, 104], [62, 64, 62], [165, 187, 213]]}
# images\Freetown-aerialview.jpg
# {'filename': 'images\\Freetown-aerialview.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[88, 102, 100], [138, 162, 171], [243, 249, 251]]}
# images\Fuerther Innenstadt Mrz 2020.jpg
# {'filename': 'images\\Fuerther Innenstadt Mrz 2020.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[61, 46, 34], [216, 209, 191], [169, 128, 77]]}
# images\Goettingen Marktplatz Oct06 Antilived.jpg
# {'filename': 'images\\Goettingen Marktplatz Oct06 Antilived.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[89, 132, 188], [80, 75, 72], [172, 162, 154]]}
# images\Hagen Rathausplatz.jpg
# {'filename': 'images\\Hagen Rathausplatz.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[177, 162, 145], [87, 73, 59], [131, 159, 176]]}
# images\Hamm Luftbild Innenstadt 2007.jpg
# {'filename': 'images\\Hamm Luftbild Innenstadt 2007.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[175, 168, 164], [65, 74, 69], [113, 113, 111]]}
# images\Heidelberg corr.jpg
# {'filename': 'images\\Heidelberg corr.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[31, 44, 40], [78, 100, 92], [171, 169, 163]]}
# images\Herne, Blick auf Europaplatz mit Kreuzkirche.jpg
# {'filename': 'images\\Herne, Blick auf Europaplatz mit Kreuzkirche.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[163, 181, 196], [102, 99, 74], [34, 37, 29]]}
# images\Hildesheim - Blick vom Berghözchen.jpg
# {'filename': 'images\\Hildesheim - Blick vom Berghözchen.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[63, 75, 50], [189, 214, 229], [146, 119, 104]]}
# images\Imagelomé20.jpg
# {'filename': 'images\\Imagelomé20.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[183, 192, 195], [56, 51, 36], [113, 106, 95]]}
# images\Ingolstadt Altes Rathaus 2012 02.jpg
# {'filename': 'images\\Ingolstadt Altes Rathaus 2012 02.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[138, 129, 128], [162, 206, 246], [54, 39, 40]]}
# images\Koblenz - Panorama von Festung Ehrenbreitstein.jpg
# {'filename': 'images\\Koblenz - Panorama von Festung Ehrenbreitstein.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[56, 68, 65], [164, 185, 200], [126, 141, 136]]}
# images\Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg
# {'filename': 'images\\Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[152, 171, 205], [59, 57, 49], [176, 161, 132]]}
# images\Libreville1.jpg
# {'filename': 'images\\Libreville1.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[186, 161, 162], [69, 53, 64], [122, 137, 187]]}
# images\Ludwigshafenmitte ausderluft.jpg
# {'filename': 'images\\Ludwigshafenmitte ausderluft.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[165, 171, 190], [54, 50, 52], [111, 107, 108]]}
# images\Malabo a 13-oct-01.jpg
# {'filename': 'images\\Malabo a 13-oct-01.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[161, 180, 194], [97, 114, 123], [55, 74, 83]]}
# images\Marcus Aurelius Arch Tripoli Libya.jpg
# {'filename': 'images\\Marcus Aurelius Arch Tripoli Libya.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[60, 59, 43], [218, 213, 207], [131, 126, 109]]}
# images\Melbourne montage 6.jpg
# {'filename': 'images\\Melbourne montage 6.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[200, 202, 191], [127, 155, 196], [74, 71, 58]]}
# images\Moers schloss 211204.jpg
# {'filename': 'images\\Moers schloss 211204.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[125, 116, 104], [62, 57, 48], [245, 243, 239]]}
# images\MonroviaLB14.png
# Error processing image images\MonroviaLB14.png: the input array must have size 3 along `channel_axis`, got (600, 800, 4)
# {'filename': 'images\\MonroviaLB14.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGBA'}
# images\Montaje de Antofagasta.jpg
# {'filename': 'images\\Montaje de Antofagasta.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[112, 86, 78], [46, 39, 45], [144, 148, 171]]}
# images\Niamey night.jpg
# {'filename': 'images\\Niamey night.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[22, 28, 43], [208, 160, 104], [87, 64, 43]]}
# images\Nicosia 01-2017 img23 View from Shacolas Tower.jpg
# {'filename': 'images\\Nicosia 01-2017 img23 View from Shacolas Tower.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[101, 134, 178], [89, 70, 55], [189, 166, 142]]}
# images\Offenbacher-mainbogen-flussabwärts001.jpg
# {'filename': 'images\\Offenbacher-mainbogen-flussabwärts001.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[214, 225, 230], [94, 100, 82], [152, 164, 85]]}
# images\Old city of Maskat.jpg
# {'filename': 'images\\Old city of Maskat.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[191, 186, 178], [82, 77, 70], [105, 160, 198]]}
# images\Panorama Nagold, Stadtkirche und Enz (1).jpg
# {'filename': 'images\\Panorama Nagold, Stadtkirche und Enz (1).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[76, 141, 247], [51, 54, 43], [160, 161, 162]]}
# images\Panoramique du centre de Tunis (3197369985) (cropped).jpg
# {'filename': 'images\\Panoramique du centre de Tunis (3197369985) (cropped).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[50, 46, 43], [123, 129, 144], [95, 95, 95]]}
# images\Paramaribo city collage.png
# {'filename': 'images\\Paramaribo city collage.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGB', 'dominant_colors': [[68, 69, 51], [224, 231, 227], [136, 134, 136]]}
# images\Perugia panoramic.jpg
# {'filename': 'images\\Perugia panoramic.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[138, 126, 115], [61, 53, 47], [209, 206, 203]]}
# images\Place de la nation2 (Tchad).jpg
# {'filename': 'images\\Place de la nation2 (Tchad).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[181, 175, 164], [128, 114, 95], [130, 153, 186]]}
# images\Place Memorial auz Heros Nationaux in Burkina Faso, 2009.jpg
# {'filename': 'images\\Place Memorial auz Heros Nationaux in Burkina Faso, 2009.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[165, 164, 187], [86, 82, 58], [197, 172, 136]]}
# images\Pointe des Almadies - Senegal.jpg
# {'filename': 'images\\Pointe des Almadies - Senegal.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[170, 184, 202], [72, 61, 43], [109, 147, 181]]}
# images\Praia Harbor.jpg
# {'filename': 'images\\Praia Harbor.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[176, 197, 224], [169, 127, 94], [91, 106, 128]]}
# images\Quartier OCH.jpg
# {'filename': 'images\\Quartier OCH.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[21, 89, 161], [178, 163, 162], [62, 68, 47]]}
# images\Recklinghausen, Rathaus -- 2015 -- 7398.jpg
# {'filename': 'images\\Recklinghausen, Rathaus -- 2015 -- 7398.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[146, 134, 114], [208, 219, 228], [59, 56, 47]]}
# images\Regensburg 08 2006 2.jpg
# {'filename': 'images\\Regensburg 08 2006 2.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[70, 62, 54], [176, 201, 227], [157, 147, 132]]}
# images\Remscheid rathaus.jpg
# {'filename': 'images\\Remscheid rathaus.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[220, 238, 246], [107, 95, 88], [164, 150, 145]]}
# images\Reutlingen Tübinger Tor 2012-04.jpg
# {'filename': 'images\\Reutlingen Tübinger Tor 2012-04.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[118, 171, 233], [204, 188, 173], [75, 64, 63]]}
# images\Salzgitter Stahlwerk.jpg
# {'filename': 'images\\Salzgitter Stahlwerk.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[139, 178, 226], [62, 90, 18], [78, 77, 59]]}
# images\San Salvador Montage.jpg
# {'filename': 'images\\San Salvador Montage.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[207, 208, 206], [106, 123, 147], [64, 66, 62]]}
# images\Santiago en invierno.jpg
# {'filename': 'images\\Santiago en invierno.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[176, 184, 191], [75, 62, 51], [103, 151, 215]]}
# images\Schloss Broich 0504.jpg
# {'filename': 'images\\Schloss Broich 0504.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[194, 221, 251], [76, 79, 78], [162, 155, 137]]}
# images\Schlosswache mit Lambertikirche.jpg
# {'filename': 'images\\Schlosswache mit Lambertikirche.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[75, 72, 59], [91, 128, 158], [198, 196, 184]]}
# images\Siegen - panoramio (9).jpg
# {'filename': 'images\\Siegen - panoramio (9).jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[150, 144, 116], [134, 180, 230], [57, 57, 53]]}
# images\Sucre capital de Bolivia.jpg
# {'filename': 'images\\Sucre capital de Bolivia.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[69, 55, 50], [205, 208, 220], [117, 116, 122]]}
# images\Tambov TransgfigurationCathedral 101 0477.jpg
# {'filename': 'images\\Tambov TransgfigurationCathedral 101 0477.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[75, 65, 53], [188, 189, 197], [142, 128, 117]]}
# images\Tegucigalpa desde el picacho en septiembre.jpg
# {'filename': 'images\\Tegucigalpa desde el picacho en septiembre.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[42, 43, 41], [208, 206, 200], [101, 107, 116]]}
# images\The National Assembly Globe.jpg
# {'filename': 'images\\The National Assembly Globe.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[216, 223, 217], [178, 211, 239], [84, 149, 191]]}
# images\Trier 126x.jpg
# {'filename': 'images\\Trier 126x.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[71, 91, 130], [166, 181, 205], [54, 66, 64]]}
# images\Ulm Donauschwabenufer1.jpg
# {'filename': 'images\\Ulm Donauschwabenufer1.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[164, 188, 230], [107, 103, 89], [41, 44, 36]]}
# images\Witten 20090218.jpg
# {'filename': 'images\\Witten 20090218.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[62, 54, 58], [122, 103, 100], [201, 184, 156]]}
# images\Белгород с аэростата 5 августа 2014 10.jpg
# {'filename': 'images\\Белгород с аэростата 5 августа 2014 10.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'exif': {'ExifOffset': 338, 'Artist': 'tamere'}, 'dominant_colors': [[46, 54, 51], [189, 182, 172], [106, 108, 100]]}
# images\Главное здание управления ЮВЖД.jpg
# {'filename': 'images\\Главное здание управления ЮВЖД.jpg', 'size': (800, 600), 'format': 'JPEG', 'mode': 'RGB', 'dominant_colors': [[48, 40, 50], [121, 140, 189], [205, 142, 117]]}
# images\Краснодар.png
# {'filename': 'images\\Краснодар.png', 'size': (800, 600), 'format': 'PNG', 'mode': 'RGB', 'dominant_colors': [[136, 118, 80], [187, 204, 218], [60, 63, 71]]}

# %% [markdown]
# ## II] Récupération des métadonnées

# %%
import os
#get all images
def get_all_images(source="images"):
    images = []
    for filename in os.listdir(source):
        if filename.endswith(".jpg"):
            images.append(filename)
    return images

# %%
# Récupération des couleurs prédominantes 
from PIL import Image
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 933120000
import numpy
import math
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

def get_color(image_path):
    imgfile = Image.open(image_path)

    numarray = numpy.array(imgfile.getdata(), numpy.uint8)
    n_clusters = 4
    clusters = KMeans(n_clusters, n_init=2)
    clusters.fit(numarray)
    npbins = numpy.arange(0, n_clusters + 1)
    histogram = numpy.histogram(clusters.labels_, bins=npbins)
    labels = numpy.unique(clusters.labels_)

    # Zip des étiquettes et des hauteurs de barres, puis tri par étiquettes
    sorted_data = sorted(zip(labels, histogram[0]), key=lambda x: x[0])

    # Récupération des étiquettes triées et des hauteurs triées
    sorted_labels, sorted_heights = zip(*sorted_data)

    # Création des histogrammes triés
    barlist = plt.bar(sorted_labels, sorted_heights)
    colors =[]
    # Coloration des histogrammes avec les couleurs des clusters
    for i in range(n_clusters):
        colors.append(
            "#%02x%02x%02x"
            % (
                math.ceil(clusters.cluster_centers_[i][0]),
                math.ceil(clusters.cluster_centers_[i][1]),
                math.ceil(clusters.cluster_centers_[i][2]),
            )
        )
        barlist[i].set_color(
        "#%02x%02x%02x"
        % (
            math.ceil(clusters.cluster_centers_[i][0]),
            math.ceil(clusters.cluster_centers_[i][1]),
            math.ceil(clusters.cluster_centers_[i][2]),
        )
        )
    #print(colors)
    return colors

# %%
# Get color for all my images files
import json

def metadata_color_images():
    images = get_all_images()
    color_metadata = {}
    for image in images:
        try:
            color_metadata[image] = get_color(f"images/{image}")
            print(color_metadata)
        except Exception as e:
            continue
    with open("color_data.json","w") as file:
        json.dump(color_metadata, file, default=str, indent=4)
    return

metadata_color_images()
# Out:
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189'], 'Freetown-aerialview.jpg': ['#4c5954', '#f6fbfd', '#9eb4bf', '#748b92']}
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189'], 'Freetown-aerialview.jpg': ['#4c5954', '#f6fbfd', '#9eb4bf', '#748b92'], 'Fuerther Innenstadt Mrz 2020.jpg': ['#c2a175', '#82613c', '#342619', '#e0d9c7']}
# ...
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189'], 'Freetown-aerialview.jpg': ['#4c5954', '#f6fbfd', '#9eb4bf', '#748b92'], 'Fuerther Innenstadt Mrz 2020.jpg': ['#c2a175', '#82613c', '#342619', '#e0d9c7'], 'Goettingen Marktplatz Oct06 Antilived.jpg': ['#4672a8', '#98b2d5', '#313231', '#736a64'], 'Hagen Rathausplatz.jpg': ['#7e9aab', '#4d4033', '#b8bab6', '#8a7b6a'], 'Hamm Luftbild Innenstadt 2007.jpg': ['#666967', '#8d8785', '#3e4741', '#c2c0bd'], 'Heidelberg corr.jpg': ['#49615b', '#c9cecd', '#1c2d25', '#85887f'], 'Herne, Blick auf Europaplatz mit Kreuzkirche.jpg': ['#a3b7c6', '#4b4d37', '#7f7a67', '#1b1f15'], 'Hildesheim - Blick vom Berghözchen.jpg': ['#bdd6e6', '#5b5f47', '#2e3b24', '#998070'], 'Imagelomé20.jpg': ['#373424', '#c0cacd', '#6e675c', '#a2a9a8'], 'Ingolstadt Altes Rathaus 2012 02.jpg': ['#332526', '#8cb7e8', '#7c7575', '#b6dbf5'], 'Koblenz - Panorama von Festung Ehrenbreitstein.jpg': ['#a7bdcd', '#596966', '#8a9c9b', '#27342e'], 'Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg': ['#36362d', '#9eb4da', '#82786a', '#e6d6b0'], 'Libreville1.jpg': ['#e5cecc', '#2e222c', '#9296ba', '#6a5b6b'], 'Ludwigshafenmitte ausderluft.jpg': ['#676363', '#b4bbce', '#8a8d9c', '#333031'], 'Malabo a 13-oct-01.jpg': ['#314348', '#a5b8c7', '#71828b', '#4c626e'], 'Marcus Aurelius Arch Tripoli Libya.jpg': ['#6f6b59', '#e9e4e1', '#a09b8e', '#363625'], 'Melbourne montage 6.jpg': ['#97b2d5', '#353427', '#eaeded', '#797f79'], 'Moers schloss 211204.jpg': ['#3a362d', '#faf9f6', '#a59f92', '#71685d'], 'Montaje de Antofagasta.jpg': ['#adb2c5', ' ...
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189'], 'Freetown-aerialview.jpg': ['#4c5954', '#f6fbfd', '#9eb4bf', '#748b92'], 'Fuerther Innenstadt Mrz 2020.jpg': ['#c2a175', '#82613c', '#342619', '#e0d9c7'], 'Goettingen Marktplatz Oct06 Antilived.jpg': ['#4672a8', '#98b2d5', '#313231', '#736a64'], 'Hagen Rathausplatz.jpg': ['#7e9aab', '#4d4033', '#b8bab6', '#8a7b6a'], 'Hamm Luftbild Innenstadt 2007.jpg': ['#666967', '#8d8785', '#3e4741', '#c2c0bd'], 'Heidelberg corr.jpg': ['#49615b', '#c9cecd', '#1c2d25', '#85887f'], 'Herne, Blick auf Europaplatz mit Kreuzkirche.jpg': ['#a3b7c6', '#4b4d37', '#7f7a67', '#1b1f15'], 'Hildesheim - Blick vom Berghözchen.jpg': ['#bdd6e6', '#5b5f47', '#2e3b24', '#998070'], 'Imagelomé20.jpg': ['#373424', '#c0cacd', '#6e675c', '#a2a9a8'], 'Ingolstadt Altes Rathaus 2012 02.jpg': ['#332526', '#8cb7e8', '#7c7575', '#b6dbf5'], 'Koblenz - Panorama von Festung Ehrenbreitstein.jpg': ['#a7bdcd', '#596966', '#8a9c9b', '#27342e'], 'Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg': ['#36362d', '#9eb4da', '#82786a', '#e6d6b0'], 'Libreville1.jpg': ['#e5cecc', '#2e222c', '#9296ba', '#6a5b6b'], 'Ludwigshafenmitte ausderluft.jpg': ['#676363', '#b4bbce', '#8a8d9c', '#333031'], 'Malabo a 13-oct-01.jpg': ['#314348', '#a5b8c7', '#71828b', '#4c626e'], 'Marcus Aurelius Arch Tripoli Libya.jpg': ['#6f6b59', '#e9e4e1', '#a09b8e', '#363625'], 'Melbourne montage 6.jpg': ['#97b2d5', '#353427', '#eaeded', '#797f79'], 'Moers schloss 211204.jpg': ['#3a362d', '#faf9f6', '#a59f92', '#71685d'], 'Montaje de Antofagasta.jpg': ['#adb2c5', ' ...
# {'00 3178 Sydney, Australia.jpg': ['#7c6c6a', '#a7a2a8', '#313234', '#687aa1'], '15-Nouakchott-eH-R0058185.jpg': ['#614c53', '#baa5ab', '#93797b', '#2b1c1f'], '20130610 - Monumento aos Heróis da Independência.jpg': ['#cba586', '#cbd6de', '#3c3a13', '#8a7656'], 'Addis abeba meskele square.jpg': ['#cdc7aa', '#3a3c32', '#69a6cf', '#867658'], 'Alger monochrome.jpg': ['#c5c5c5', '#0e0e0e', '#3f3f3f', '#828282'], 'Algiers Grand Post.jpg': ['#0a080b', '#93939f', '#5d5452', '#c2c4c4'], 'Algiers in the morning.jpg': ['#7f7764', '#c2baac', '#201c14', '#4e4431'], "Algiers's Airport.jpg": ['#29301a', '#839972', '#c8e4cf', '#546540'], 'AMMAN 2.jpg': ['#b59a82', '#2d1f17', '#785f4c', '#f6f4ee'], 'AnkonPanorama.jpg': ['#323739', '#857d80', '#5c5c5e', '#969fb7'], 'Argel 3.jpg': ['#2a3032', '#c6c5c6', '#7f8c9f', '#5e5e5c'], 'Asmara2.jpg': ['#bda586', '#7c6852', '#3a3125', '#566781'], 'Asunción Paraguay.jpg': ['#aabaca', '#55554c', '#262721', '#898682'], 'At night in Algiers, Algeria.jpg': ['#151a23', '#084e9f', '#999890', '#57534a'], 'Ausblick Bergisch Gladbach.jpg': ['#bbd2df', '#5d6960', '#283025', '#eefcfc'], 'Avenida Bolivar A Chavez.jpg': ['#192a1f', '#d1d0a6', '#495742', '#947a53'], 'Bangui City Centre.jpg': ['#b5bec4', '#615038', '#ea9a67', '#b27b51'], 'Beirutcity.jpg': ['#10182a', '#3e8ac9', '#2a426f', '#878a99'], 'Beograd collage.jpg': ['#dee8ea', '#596468', '#7ea5c0', '#2b2d25'], 'Blick vom Rathausturm über Gera.jpg': ['#5b524b', '#bfc7d5', '#918378', '#282421'], 'Bottrop - Altmarkt 02 ies.jpg': ['#99979c', '#27282c', '#aad4fb', '#636770'], 'Canberra from Mt Ainslie (5642431515).jpg': ['#545350', '#817d81', '#302d1f', '#a8b1c5'], 'Central accra-2.jpg': ['#dededd', '#5e5d56', '#807e79', '#a9a5a4'], 'Central Algeria at night.jpg': ['#120804', '#e4ab5b', '#984e17', '#4f1e07'], 'CintaCosteraPanama.jpg': ['#353327', '#c5d2df', '#a18b6a', '#6a9cda'], 'Cityscape of San José, Costa Rica (253552473).jpg': ['#231e1d', '#ddc2b9', '#4c4746', '#817471'], 'Cottbus 07-2017 img10 aerial.jpg': ['#c5c6cc', '#364239', '#8fa6c4', '#6f6f72'], 'Damascus, Syria, Panorama at sunset.jpg': ['#343733', '#c1bcb6', '#928c85', '#64625d'], 'Djibouti City.jpg': ['#938c8a', '#d6dceb', '#292a24', '#5f5a59'], 'Dom R1.jpg': ['#695b57', '#292522', '#96807c', '#b0bcc8'], 'Dom zu paderborn1.jpg': ['#c5c7bf', '#3f3e3e', '#687bbb', '#88857f'], 'Elizabeth Quay February 2016 (cropped).jpg': ['#bcc3d1', '#303b48', '#737677', '#7d9bcc'], 'Erlangen 08-2012.jpg': ['#a7bfd9', '#71615a', '#303531', '#aa9189'], 'Freetown-aerialview.jpg': ['#4c5954', '#f6fbfd', '#9eb4bf', '#748b92'], 'Fuerther Innenstadt Mrz 2020.jpg': ['#c2a175', '#82613c', '#342619', '#e0d9c7'], 'Goettingen Marktplatz Oct06 Antilived.jpg': ['#4672a8', '#98b2d5', '#313231', '#736a64'], 'Hagen Rathausplatz.jpg': ['#7e9aab', '#4d4033', '#b8bab6', '#8a7b6a'], 'Hamm Luftbild Innenstadt 2007.jpg': ['#666967', '#8d8785', '#3e4741', '#c2c0bd'], 'Heidelberg corr.jpg': ['#49615b', '#c9cecd', '#1c2d25', '#85887f'], 'Herne, Blick auf Europaplatz mit Kreuzkirche.jpg': ['#a3b7c6', '#4b4d37', '#7f7a67', '#1b1f15'], 'Hildesheim - Blick vom Berghözchen.jpg': ['#bdd6e6', '#5b5f47', '#2e3b24', '#998070'], 'Imagelomé20.jpg': ['#373424', '#c0cacd', '#6e675c', '#a2a9a8'], 'Ingolstadt Altes Rathaus 2012 02.jpg': ['#332526', '#8cb7e8', '#7c7575', '#b6dbf5'], 'Koblenz - Panorama von Festung Ehrenbreitstein.jpg': ['#a7bdcd', '#596966', '#8a9c9b', '#27342e'], 'Leverkusen-Schloss-Morsbroich Hauptgebäude.jpg': ['#36362d', '#9eb4da', '#82786a', '#e6d6b0'], 'Libreville1.jpg': ['#e5cecc', '#2e222c', '#9296ba', '#6a5b6b'], 'Ludwigshafenmitte ausderluft.jpg': ['#676363', '#b4bbce', '#8a8d9c', '#333031'], 'Malabo a 13-oct-01.jpg': ['#314348', '#a5b8c7', '#71828b', '#4c626e'], 'Marcus Aurelius Arch Tripoli Libya.jpg': ['#6f6b59', '#e9e4e1', '#a09b8e', '#363625'], 'Melbourne montage 6.jpg': ['#97b2d5', '#353427', '#eaeded', '#797f79'], 'Moers schloss 211204.jpg': ['#3a362d', '#faf9f6', '#a59f92', '#71685d'], 'Montaje de Antofagasta.jpg': ['#adb2c5', ' ...

# %% [markdown]
# # III] Mise en place des tags sur les images #

# %%
from transformers import ViTImageProcessor, ViTForImageClassification
from PIL import Image
import requests

image_path = "images/Paris.jpg"
image = Image.open(image_path)

processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')

inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
# model predicts one of the 1000 ImageNet classes
predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from transformers import ViTImageProcessor, ViTForImageClassification
#       2 from PIL import Image
#       3 import requests
#
# ModuleNotFoundError: No module named 'transformers'
